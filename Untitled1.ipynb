# %%
import pickle
import matplotlib.pyplot as plt

# %%
infile = open('pickle/Real,fixed scheduler,SGD','rb')
#'Real,fixed scheduler,SGD'/'0,Real,scheduler,Adam'
lossesR = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Realtest,fixed scheduler,SGD','rb')
#'Real,fixed scheduler,SGD'/'0,Real,scheduler,Adam'
lossesRt = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Complex,fixed scheduler,SGD','rb')
#'Complex,scheduler,Adam','Complex,fixed scheduler,SGD'
lossesC = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Complextest,fixed scheduler,SGD','rb')
#'Complex,scheduler,Adam','Complex,fixed scheduler,SGD'
lossesCt = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/without NG,fixed scheduler,SGD','rb')
#'without NG,fixed scheduler,SGD','Nature,scheduler,Adam'
lossesN = pickle.load(infile)
infile.close()

# %%
plot0 = plt.plot(lossesR)
plot1 = plt.plot(lossesCt)
plot2 = plt.plot(lossesN)
plt.title("Regulazation=0.1, SGD, fixed LR scheduler")
plt.legend((plot0[0],plot1[0],plot2[0]),("Real","Complex","Vanilla"))

# %%
plot0 = plt.plot(lossesR)
plot1 = plt.plot(lossesRt)
plot2 = plt.plot(lossesN)
plt.title("Regulazation=0.1, SGD, fixed LR scheduler")
plt.legend((plot0[0],plot1[0],plot2[0]),("Real","Real test","Vanilla"))

# %%
plot0 = plt.plot(lossesC)
plot1 = plt.plot(lossesCt)
plot2 = plt.plot(lossesN)
plt.title("Regulazation=0.1, SGD, fixed LR scheduler")
plt.legend((plot0[0],plot1[0],plot2[0]),("Complex","Complex test","Vanilla"))
