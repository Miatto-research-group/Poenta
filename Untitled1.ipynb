# %%
import pickle
import matplotlib.pyplot as plt

# %%
infile = open('pickle/Real,Re(G)','rb')
losses1 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Complex,Re(G)','rb')
losses2 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Complex,G+GT','rb')
losses3 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Vanilla','rb')
losses4 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Real,G','rb')
losses5 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/Complex,G','rb')
losses6 = pickle.load(infile)
infile.close()

# %%
infile = open('pickle/test','rb')
losses7 = pickle.load(infile)
infile.close()

# %%
plot0 = plt.plot(losses1[:400])
plot1 = plt.plot(losses2[:400])
plot2 = plt.plot(losses3[:400])
plot3 = plt.plot(losses4[:400])
plot4 = plt.plot(losses5[:400])
plot5 = plt.plot(losses6[:400])
plot6 = plt.plot(losses7[:400])
plt.title("Regulazation=0.1, SGD, fixed LR scheduler=0.001")
plt.legend((plot0[0],plot1[0],plot2[0],plot3[0],plot4[0],plot5[0],plot6[0]),("REAL_Re(G)","COMPLEX_Re(G)","COMPLEX_G+GT",'Vanilla',"Real_G","COMPLEX_G","COMPLEX_G+GT_PART"))
plt.text(0,-0.2,"G means <dpsi|dpsi>-<dpsi|psi><psi|dpsi>")
plt.text(0,-0.3,"Re(G) means np.real(G)")
plt.text(0,-0.4,"G+GT means G+GT/2")
plt.text(430,1,"Real means real params")
plt.text(430,0.9,"COMPLEX means complex params")
plt.text(430,0.8,"Vanilla means without NG")
# Out:
# Text(430, 0.8, 'Vanilla means without NG')

# %%
plot2 = plt.plot(losses3[:400])
plot6 = plt.plot(losses7[:400])
plt.title("Regulazation=0.1, SGD, fixed LR scheduler=0.001")
plt.legend((plot2[0],plot6[0]),("COMPLEX_G+GT","COMPLEX_G+GT_PART"))
