# %%
import pickle
import matplotlib.pyplot as plt

# %%
infile = open('pickle/Vanilla665','rb')
losses4 = pickle.load(infile)
infile.close()
infile = open('pickle/Complex665','rb')
lossesC = pickle.load(infile)
infile.close()
infile = open('pickle/Real665','rb')
lossesR = pickle.load(infile)
infile.close()

# %%
plot4 = plt.plot(losses4)
plot6 = plt.plot(lossesC)
plot2 = plt.plot(lossesR)
plt.title("Regulazation=0.004, SGD, not fixed LR scheduler")
plt.legend((plot4[0],plot2[0],plot6[0]),("Vanilla","Real","Complex"))
