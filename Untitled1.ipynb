# %%
import pickle
import matplotlib.pyplot as plt

# %%
infile = open('0,REAL,gammac,scheduler,Adam','rb')
lossesR = pickle.load(infile)
infile.close()

# %%
infile = open('Complex,scheduler,Adam','rb')
lossesC = pickle.load(infile)
infile.close()

# %%
infile = open('Nature,scheduler,Adam','rb')
lossesN = pickle.load(infile)
infile.close()

# %%
plot0 = plt.plot(lossesR)
plot1 = plt.plot(lossesC)
plot2 = plt.plot(lossesN)
plt.legend((plot0[0],plot1[0],plot2[0]),("adam Real","adam complex","adam nature"))
