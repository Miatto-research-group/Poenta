# %%
W1 = {{Exp[i*phi1],0},{0,Exp[i*phi2]}}
# Out:
#    i phi1           i phi2
# {{E      , 0}, {0, E      }}

# %%
W2 = {{Cos[theta2],-Exp[-i*varphi2]*Sin[theta2]},{Exp[i*varphi2]*Sin[theta2],Cos[theta2]}}
# Out:
#                  Sin[theta2]      i varphi2
# {{Cos[theta2], -(-----------)}, {E          Sin[theta2], Cos[theta2]}}
#                   i varphi2
#                  E

# %%
V = {{Cos[theta1],-Exp[-i*varphi1]*Sin[theta1]},{Exp[i*varphi1]*Sin[theta1],Cos[theta1]}}
# Out:
#                  Sin[theta1]      i varphi1
# {{Cos[theta1], -(-----------)}, {E          Sin[theta1], Cos[theta1]}}
#                   i varphi1
#                  E

# %%
W = W1.W2
# Out:
#    i phi1                 i phi1 - i varphi2
# {{E       Cos[theta2], -(E                   Sin[theta2])},
#
#       i phi2 + i varphi2               i phi2
# >   {E                   Sin[theta2], E       Cos[theta2]}}

# %%
WT = Transpose[W]
# Out:
#    i phi1               i phi2 + i varphi2
# {{E       Cos[theta2], E                   Sin[theta2]},
#
#         i phi1 - i varphi2                i phi2
# >   {-(E                   Sin[theta2]), E       Cos[theta2]}}

# %%
G = {gamma1,gamma2}
# Out:
# {gamma1, gamma2}

# %%
G1 = {Conjugate[gamma1] , Conjugate[gamma2]}
# Out:
# {Conjugate[gamma1], Conjugate[gamma2]}

# %%
G2 = {{Conjugate[gamma1]},{Conjugate[gamma2]}}
# Out:
# {{Conjugate[gamma1]}, {Conjugate[gamma2]}}

# %%
T = {{Exp[i*delta1]*tanh[r1],0},{0,Exp[i*delta2]*tanh[r2]}}
# Out:
#    delta1 i                    delta2 i
# {{E         tanh[r1], 0}, {0, E         tanh[r2]}}

# %%
T = {{T1,0},{0,T2}}
# Out:
# {{T1, 0}, {0, T2}}

# %% [markdown]
# <h1>mu</h1>

# %%
mu1 = G1.W.T.WT
# Out:
#     i phi1 - i varphi2
# {-(E                   T2 Sin[theta2]
#
#           i phi2
# >       (E       Conjugate[gamma2] Cos[theta2] -
#
#            i phi1 - i varphi2
# >         E                   Conjugate[gamma1] Sin[theta2])) +
#
#       i phi1                  i phi1
# >    E       T1 Cos[theta2] (E       Conjugate[gamma1] Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   Conjugate[gamma2] Sin[theta2]),
#
#      i phi2                  i phi2
# >   E       T2 Cos[theta2] (E       Conjugate[gamma2] Cos[theta2] -
#
#          i phi1 - i varphi2
# >       E                   Conjugate[gamma1] Sin[theta2]) +
#
#       i phi2 + i varphi2
# >    E                   T1 Sin[theta2]
#
#         i phi1
# >     (E       Conjugate[gamma1] Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   Conjugate[gamma2] Sin[theta2])}

# %%
mu12 = mu1+G
# Out:
#            i phi1 - i varphi2
# {gamma1 - E                   T2 Sin[theta2]
#
#         i phi2
# >     (E       Conjugate[gamma2] Cos[theta2] -
#
#          i phi1 - i varphi2
# >       E                   Conjugate[gamma1] Sin[theta2]) +
#
#       i phi1                  i phi1
# >    E       T1 Cos[theta2] (E       Conjugate[gamma1] Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   Conjugate[gamma2] Sin[theta2]),
#
#               i phi2
# >   gamma2 + E       T2 Cos[theta2]
#
#         i phi2
# >     (E       Conjugate[gamma2] Cos[theta2] -
#
#          i phi1 - i varphi2
# >       E                   Conjugate[gamma1] Sin[theta2]) +
#
#       i phi2 + i varphi2
# >    E                   T1 Sin[theta2]
#
#         i phi1
# >     (E       Conjugate[gamma1] Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   Conjugate[gamma2] Sin[theta2])}

# %%
FullSimplify[mu12]
# Out:
#            i (phi1 + phi2 - varphi2)   2 i varphi2
# {gamma1 + E                          (E            T1 - T2) Conjugate[gamma2]
#
#                                  2 i (phi1 - varphi2)
# >     Cos[theta2] Sin[theta2] + E                     Conjugate[gamma1]
#
#         2 i varphi2               2                 2
# >     (E            T1 Cos[theta2]  + T2 Sin[theta2] ),
#
#               i (phi1 + phi2 - varphi2)   2 i varphi2
# >   gamma2 + E                          (E            T1 - T2) Conjugate[gamma1]
#
#                                  2 i phi2
# >     Cos[theta2] Sin[theta2] + E         Conjugate[gamma2]
#
#                      2    2 i varphi2               2
# >     (T2 Cos[theta2]  + E            T1 Sin[theta2] )}

# %%
S = {{Sech[r1],0},{0,Sech[r2]}}
# Out:
# {{Sech[r1], 0}, {0, Sech[r2]}}

# %%
mu2 = -G1.W.S.V
# Out:
#     i varphi1                        i phi2
# {-(E          Sech[r2] Sin[theta1] (E       Conjugate[gamma2] Cos[theta2] -
#
#            i phi1 - i varphi2
# >         E                   Conjugate[gamma1] Sin[theta2])) -
#
#                             i phi1
# >    Cos[theta1] Sech[r1] (E       Conjugate[gamma1] Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   Conjugate[gamma2] Sin[theta2]),
#
#                              i phi2
# >   -(Cos[theta1] Sech[r2] (E       Conjugate[gamma2] Cos[theta2] -
#
#            i phi1 - i varphi2
# >         E                   Conjugate[gamma1] Sin[theta2])) +
#
#                              i phi1
# >    (Sech[r1] Sin[theta1] (E       Conjugate[gamma1] Cos[theta2] +
#
#            i phi2 + i varphi2                                    i varphi1
# >         E                   Conjugate[gamma2] Sin[theta2])) / E         }

# %%
FullSimplify[mu2]
# Out:
#                        i (phi2 + varphi1)
# {-(Conjugate[gamma2] (E                   Cos[theta2] Sech[r2] Sin[theta1] +
#
#            i (phi2 + varphi2)
# >         E                   Cos[theta1] Sech[r1] Sin[theta2])) +
#
#                            i phi1
# >    Conjugate[gamma1] (-(E       Cos[theta1] Cos[theta2] Sech[r1]) +
#
#          i (phi1 + varphi1 - varphi2)
# >       E                             Sech[r2] Sin[theta1] Sin[theta2]),
#
#                              i phi2
# >   -(Cos[theta1] Sech[r2] (E       Conjugate[gamma2] Cos[theta2] -
#
#            i (phi1 - varphi2)
# >         E                   Conjugate[gamma1] Sin[theta2])) +
#
#                              i phi1
# >    (Sech[r1] Sin[theta1] (E       Conjugate[gamma1] Cos[theta2] +
#
#            i (phi2 + varphi2)                                    i varphi1
# >         E                   Conjugate[gamma2] Sin[theta2])) / E         }

# %%
Simplify[D[mu12,r2]]
# Out:
# {0, 0}

# %%
Simplify[D[mu12,varphi2]]
# Out:
#   i (phi1 - 2 varphi2)
# {E                     i Sin[theta2]
#
#        i (phi2 + varphi2)   2 i varphi2
# >    (E                   (E            T1 + T2) Conjugate[gamma2] Cos[theta2] -
#
#           i phi1
# >      2 E       T2 Conjugate[gamma1] Sin[theta2]),
#
#      i (phi2 - varphi2)
# >   E                   i Sin[theta2]
#
#        i phi1   2 i varphi2
# >    (E       (E            T1 + T2) Conjugate[gamma1] Cos[theta2] +
#
#           i (phi2 + 3 varphi2)
# >      2 E                     T1 Conjugate[gamma2] Sin[theta2])}

# %%
Simplify[D[mu2,varphi2]]
# Out:
#         i (phi2 + 2 varphi2)
# {-((i (E                     Conjugate[gamma2] Cos[theta1] Sech[r1] +
#
#             i (phi1 + varphi1)
# >          E                   Conjugate[gamma1] Sech[r2] Sin[theta1]) Sin[theta2]) /
#
#         i varphi2          i (phi1 + varphi1)
# >      E         ), (i (-(E                   Conjugate[gamma1] Cos[theta1] Sech[r2]) +
#
#           i (phi2 + 2 varphi2)
# >        E                     Conjugate[gamma2] Sech[r1] Sin[theta1]) Sin[theta2]) /
#
#       i (varphi1 + varphi2)
# >    E                     }

# %% [markdown]
# <h1>C = EXP(Part1+Part2)</h1>

# %%
Part2 = G1.W.T.WT.G2
# Out:
#                        i phi1 - i varphi2
# {Conjugate[gamma1] (-(E                   T2 Sin[theta2]
#
#              i phi2
# >          (E       Conjugate[gamma2] Cos[theta2] -
#
#               i phi1 - i varphi2
# >            E                   Conjugate[gamma1] Sin[theta2])) +
#
#          i phi1                  i phi1
# >       E       T1 Cos[theta2] (E       Conjugate[gamma1] Cos[theta2] +
#
#             i phi2 + i varphi2
# >          E                   Conjugate[gamma2] Sin[theta2])) +
#
#                          i phi2
# >    Conjugate[gamma2] (E       T2 Cos[theta2]
#
#            i phi2
# >        (E       Conjugate[gamma2] Cos[theta2] -
#
#             i phi1 - i varphi2
# >          E                   Conjugate[gamma1] Sin[theta2]) +
#
#          i phi2 + i varphi2
# >       E                   T1 Sin[theta2]
#
#            i phi1
# >        (E       Conjugate[gamma1] Cos[theta2] +
#
#             i phi2 + i varphi2
# >          E                   Conjugate[gamma2] Sin[theta2]))}

# %%
Simplify[Part2]
# Out:
#                    2   2 i (phi2 + varphi2)               2
# {(Conjugate[gamma2]  (E                     T2 Cos[theta2]  +
#
#            2 i (phi2 + 2 varphi2)               2
# >         E                       T1 Sin[theta2] ) +
#
#         2 i phi1                  2   2 i varphi2               2                 2
# >      E         Conjugate[gamma1]  (E            T1 Cos[theta2]  + T2 Sin[theta2] ) +
#
#          i (phi1 + phi2 + 3 varphi2)       i (phi1 + phi2 + varphi2)
# >      (E                            T1 - E                          T2)
#
#                                                               2 i varphi2
# >       Conjugate[gamma1] Conjugate[gamma2] Sin[2 theta2]) / E           }

# %%
Part1 = G.G2
# Out:
# {gamma1 Conjugate[gamma1] + gamma2 Conjugate[gamma2]}

# %%
D[Part1,theta1]
# Out:
# {0}

# %%
Simplify[D[Part2,delta1]]
# Out:
# {0}

# %% [markdown]
# <h1>Sigma Matrix</h1>

# %%
T = {{Exp[i*delta1]*tanh[r1],0},{0,Exp[i*delta2]*tanh[r2]}}
# Out:
#    delta1 i                    delta2 i
# {{E         tanh[r1], 0}, {0, E         tanh[r2]}}

# %%
Sigma1 = W.T.WT
# Out:
#    delta1 i + 2 i phi1            2
# {{E                    Cos[theta2]  tanh[r1] +
#
#        delta2 i + 2 i phi1 - 2 i varphi2            2
# >     E                                  Sin[theta2]  tanh[r2],
#
#       delta1 i + i phi1 + i phi2 + i varphi2
# >    E                                       Cos[theta2] Sin[theta2] tanh[r1] -
#
#        delta2 i + i phi1 + i phi2 - i varphi2
# >     E                                       Cos[theta2] Sin[theta2] tanh[r2]},
#
#       delta1 i + i phi1 + i phi2 + i varphi2
# >   {E                                       Cos[theta2] Sin[theta2] tanh[r1] -
#
#        delta2 i + i phi1 + i phi2 - i varphi2
# >     E                                       Cos[theta2] Sin[theta2] tanh[r2],
#
#       delta1 i + 2 i phi2 + 2 i varphi2            2
# >    E                                  Sin[theta2]  tanh[r1] +
#
#        delta2 i + 2 i phi2            2
# >     E                    Cos[theta2]  tanh[r2]}}

# %%
Simplify[D[Sigma1,delta2]]
# Out:
#    i (delta2 + 2 phi1 - 2 varphi2)              2
# {{E                                i Sin[theta2]  tanh[r2],
#
#         i (delta2 + phi1 + phi2 - varphi2)
# >    -(E                                   i Cos[theta2] Sin[theta2] tanh[r2])},
#
#         i (delta2 + phi1 + phi2 - varphi2)
# >   {-(E                                   i Cos[theta2] Sin[theta2] tanh[r2]),
#
#       i (delta2 + 2 phi2)              2
# >    E                    i Cos[theta2]  tanh[r2]}}

# %%
Sigma2 = -W.S.V
# Out:
#      i phi1
# {{-(E       Cos[theta1] Cos[theta2] Sech[r1]) +
#
#        i phi1 + i varphi1 - i varphi2
# >     E                               Sech[r2] Sin[theta1] Sin[theta2],
#
#       i phi1 - i varphi1
# >    E                   Cos[theta2] Sech[r1] Sin[theta1] +
#
#        i phi1 - i varphi2
# >     E                   Cos[theta1] Sech[r2] Sin[theta2]},
#
#         i phi2 + i varphi1
# >   {-(E                   Cos[theta2] Sech[r2] Sin[theta1]) -
#
#        i phi2 + i varphi2
# >     E                   Cos[theta1] Sech[r1] Sin[theta2],
#
#         i phi2
# >    -(E       Cos[theta1] Cos[theta2] Sech[r2]) +
#
#        i phi2 - i varphi1 + i varphi2
# >     E                               Sech[r1] Sin[theta1] Sin[theta2]}}

# %%
Simplify[D[Sigma2,r2]]
# Out:
#      i (phi1 + varphi1 - varphi2)
# {{-(E                             Sech[r2] Sin[theta1] Sin[theta2] Tanh[r2]),
#
#         i (phi1 - varphi2)
# >    -(E                   Cos[theta1] Sech[r2] Sin[theta2] Tanh[r2])},
#
#       i (phi2 + varphi1)
# >   {E                   Cos[theta2] Sech[r2] Sin[theta1] Tanh[r2],
#
#       i phi2
# >    E       Cos[theta1] Cos[theta2] Sech[r2] Tanh[r2]}}

# %%
VT = Transpose[V]
# Out:
#                 i varphi1                  Sin[theta1]
# {{Cos[theta1], E          Sin[theta1]}, {-(-----------), Cos[theta1]}}
#                                             i varphi1
#                                            E

# %%
Tminus = {{Exp[-i*delta1]*tanh[r1],0},{0,Exp[-i*delta2]*tanh[r2]}}
# Out:
#   tanh[r1]           tanh[r2]
# {{---------, 0}, {0, ---------}}
#    delta1 i           delta2 i
#   E                  E

# %%
Tminus = {{Tminus1,0},{0,Tminus2}}
# Out:
# {{Tminus1, 0}, {0, Tminus2}}

# %%
Sigma4 = -VT.Tminus.V
# Out:
#                2
#     Cos[theta1]  tanh[r1]     -(delta2 i) + 2 i varphi1            2
# {{-(---------------------) - E                          Sin[theta1]  tanh[r2],
#            delta1 i
#           E
#
#       -(delta1 i) - i varphi1
# >    E                        Cos[theta1] Sin[theta1] tanh[r1] -
#
#        -(delta2 i) + i varphi1
# >     E                        Cos[theta1] Sin[theta1] tanh[r2]},
#
#       -(delta1 i) - i varphi1
# >   {E                        Cos[theta1] Sin[theta1] tanh[r1] -
#
#        -(delta2 i) + i varphi1
# >     E                        Cos[theta1] Sin[theta1] tanh[r2],
#
#                                                                       2
#         -(delta1 i) - 2 i varphi1            2             Cos[theta1]  tanh[r2]
# >    -(E                          Sin[theta1]  tanh[r1]) - ---------------------}}
#                                                                   delta2 i
#                                                                  E

# %%
Simplify[D[Sigma4,r1]]
# Out:
#                2
#     Cos[theta1]  tanh'[r1]   Cos[theta1] Sin[theta1] tanh'[r1]
# {{-(----------------------), ---------------------------------},
#            delta1 i                 i (delta1 + varphi1)
#           E                        E
#
#                                                      2
#      Cos[theta1] Sin[theta1] tanh'[r1]    Sin[theta1]  tanh'[r1]
# >   {---------------------------------, -(-----------------------)}}
#             i (delta1 + varphi1)           i (delta1 + 2 varphi1)
#            E                              E
