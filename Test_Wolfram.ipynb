# %%
W1 = {{Exp[i*phi1],0},{0,Exp[i*phi2]}}
# Out:
#    i phi1           i phi2
# {{E      , 0}, {0, E      }}

# %%
W2 = {{Cos[theta2],-Exp[-i*varphi2]*Sin[theta2]},{Exp[i*varphi2]*Sin[theta2],Cos[theta2]}}
# Out:
#                  Sin[theta2]      i varphi2
# {{Cos[theta2], -(-----------)}, {E          Sin[theta2], Cos[theta2]}}
#                   i varphi2
#                  E

# %%
V = {{Cos[theta1],-Exp[-i*varphi1]*Sin[theta1]},{Exp[i*varphi1]*Sin[theta1],Cos[theta1]}}
# Out:
#                  Sin[theta1]      i varphi1
# {{Cos[theta1], -(-----------)}, {E          Sin[theta1], Cos[theta1]}}
#                   i varphi1
#                  E

# %%
W = W1.W2
# Out:
#    i phi1                 i phi1 - i varphi2
# {{E       Cos[theta2], -(E                   Sin[theta2])},
#
#       i phi2 + i varphi2               i phi2
# >   {E                   Sin[theta2], E       Cos[theta2]}}

# %%
WT = Transpose[W]
# Out:
#    i phi1               i phi2 + i varphi2
# {{E       Cos[theta2], E                   Sin[theta2]},
#
#         i phi1 - i varphi2                i phi2
# >   {-(E                   Sin[theta2]), E       Cos[theta2]}}

# %%
T = {{Exp[i*delta1]*tanh[r1],0},{0,Exp[i*delta2]*tanh[r2]}}
# Out:
#    delta1 j                    delta2 j
# {{E         tanh[r1], 0}, {0, E         tanh[r2]}}

# %%
T = {{T1,0},{0,T2}}
# Out:
# {{T1, 0}, {0, T2}}

# %%
G1 = {gamma1 , gamma2}
# Out:
# {gamma1, gamma2}

# %%
G2 = {{Conjugate[gamma1]},{Conjugate[gamma2]}}
# Out:
# {{Conjugate[gamma1]}, {Conjugate[gamma2]}}

# %%
Part2 = G1.W.T.WT.G2
# Out:
#                        i phi1 - i varphi2
# {Conjugate[gamma1] (-(E                   T2 Sin[theta2]
#
#              i phi2                       i phi1 - i varphi2
# >          (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2])) +
#
#          i phi1                  i phi1
# >       E       T1 Cos[theta2] (E       gamma1 Cos[theta2] +
#
#             i phi2 + i varphi2
# >          E                   gamma2 Sin[theta2])) +
#
#                          i phi2
# >    Conjugate[gamma2] (E       T2 Cos[theta2]
#
#            i phi2                       i phi1 - i varphi2
# >        (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2]) +
#
#          i phi2 + i varphi2
# >       E                   T1 Sin[theta2]
#
#            i phi1                       i phi2 + i varphi2
# >        (E       gamma1 Cos[theta2] + E                   gamma2 Sin[theta2]))}

# %%
Simplify[Part2]
# Out:
#                       2 i (phi2 + varphi2)                      2
# {(Conjugate[gamma2] (E                     gamma2 T2 Cos[theta2]  +
#
#                    i (phi1 + phi2 + 3 varphi2)       i (phi1 + phi2 + varphi2)
# >         gamma1 (E                            T1 - E                          T2)
#
#                                       2 i (phi2 + 2 varphi2)                      2
# >          Cos[theta2] Sin[theta2] + E                       gamma2 T1 Sin[theta2] ) +
#
#                            2 i (phi1 + varphi2)                      2
# >      Conjugate[gamma1] (E                     gamma1 T1 Cos[theta2]  +
#
#                    i (phi1 + phi2 + 3 varphi2)       i (phi1 + phi2 + varphi2)
# >         gamma2 (E                            T1 - E                          T2)
#
#                                       2 i phi1                      2      2 i varphi2
# >          Cos[theta2] Sin[theta2] + E         gamma1 T2 Sin[theta2] )) / E           }

# %%
Part1 = G1.G2
# Out:
# {gamma1 Conjugate[gamma1] + gamma2 Conjugate[gamma2]}

# %%
D[Part1,r1]
# Out:
# {0}

# %%
Simplify[D[Part2,r1]]
# Out:
# {0}

# %%
mu1 = G1.W.T.WT
# Out:
#     i phi1 - i varphi2
# {-(E                   T2 Sin[theta2]
#
#           i phi2                       i phi1 - i varphi2
# >       (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2])) +
#
#       i phi1                  i phi1
# >    E       T1 Cos[theta2] (E       gamma1 Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   gamma2 Sin[theta2]),
#
#      i phi2                  i phi2
# >   E       T2 Cos[theta2] (E       gamma2 Cos[theta2] -
#
#          i phi1 - i varphi2
# >       E                   gamma1 Sin[theta2]) +
#
#       i phi2 + i varphi2
# >    E                   T1 Sin[theta2]
#
#         i phi1                       i phi2 + i varphi2
# >     (E       gamma1 Cos[theta2] + E                   gamma2 Sin[theta2])}

# %%
mu1+G1
# Out:
#            i phi1 - i varphi2
# {gamma1 - E                   T2 Sin[theta2]
#
#         i phi2                       i phi1 - i varphi2
# >     (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2]) +
#
#       i phi1                  i phi1
# >    E       T1 Cos[theta2] (E       gamma1 Cos[theta2] +
#
#          i phi2 + i varphi2
# >       E                   gamma2 Sin[theta2]),
#
#               i phi2
# >   gamma2 + E       T2 Cos[theta2]
#
#         i phi2                       i phi1 - i varphi2
# >     (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2]) +
#
#       i phi2 + i varphi2
# >    E                   T1 Sin[theta2]
#
#         i phi1                       i phi2 + i varphi2
# >     (E       gamma1 Cos[theta2] + E                   gamma2 Sin[theta2])}

# %%
Simpify[D[mu1,phi1]]
# Out:
#           2 i phi1                        2
# Simpify[{E         gamma1 i T1 Cos[theta2]  +
#
#        2 i phi1 - 2 i varphi2                        2
# >     E                       gamma1 i T2 Sin[theta2]  -
#
#        i phi1 - i varphi2
# >     E                   i T2 Sin[theta2]
#
#          i phi2                       i phi1 - i varphi2
# >      (E       gamma2 Cos[theta2] - E                   gamma1 Sin[theta2]) +
#
#        i phi1                    i phi1
# >     E       i T1 Cos[theta2] (E       gamma1 Cos[theta2] +
#
#           i phi2 + i varphi2
# >        E                   gamma2 Sin[theta2]),
#
#       i phi1 + i phi2 + i varphi2
# >    E                            gamma1 i T1 Cos[theta2] Sin[theta2] -
#
#        i phi1 + i phi2 - i varphi2
# >     E                            gamma1 i T2 Cos[theta2] Sin[theta2]}]
